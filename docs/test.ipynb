# %%
couverture = [25,45,6,8,12]
support_couverture = [12,10,4,12,0]
couche_1 = [2.8,0]
couche_2 = [3.45,5,0]
Finition = [17]
marge = 5

value = []

for i1 in couverture:
    for i2 in support_couverture:
        for i3 in couche_1:
            for i4 in couche_2:
                for i5 in Finition:
                    value.append(round(i1+i2+i3+i4+i5+marge))
                    print (i1+i2+i3+i4+i5+marge)

value = sorted(list(set(value)))
print(value)
# Out:
# 65.25
# 66.8
# 61.8
# 62.45
# 64
# 59
# 63.25
# 64.8
# 59.8
# 60.45
# 62
# 57
# 57.25
# 58.8
# 53.8
# 54.45
# 56
# 51
# 65.25
# 66.8
# 61.8
# 62.45
# 64
# 59
# 53.25
# 54.8
# 49.8
# 50.45
# 52
# 47
# 85.25
# 86.8
# 81.8
# 82.45
# 84
# 79
# 83.25
# 84.8
# 79.8
# 80.45
# 82
# 77
# 77.25
# 78.8
# 73.8
# 74.45
# 76
# 71
# 85.25
# 86.8
# 81.8
# 82.45
# 84
# 79
# 73.25
# 74.8
# 69.8
# 70.45
# 72
# 67
# 46.25
# 47.8
# 42.8
# 43.45
# 45
# 40
# 44.25
# 45.8
# 40.8
# 41.45
# 43
# 38
# 38.25
# 39.8
# 34.8
# 35.45
# 37
# 32
# 46.25
# 47.8
# 42.8
# 43.45
# 45
# 40
# 34.25
# 35.8
# 30.8
# 31.45
# 33
# 28
# 48.25
# 49.8
# 44.8
# 45.45
# 47
# 42
# 46.25
# 47.8
# 42.8
# 43.45
# 45
# 40
# 40.25
# 41.8
# 36.8
# 37.45
# 39
# 34
# 48.25
# 49.8
# 44.8
# 45.45
# 47
# 42
# 36.25
# 37.8
# 32.8
# 33.45
# 35
# 30
# 52.25
# 53.8
# 48.8
# 49.45
# 51
# 46
# 50.25
# 51.8
# 46.8
# 47.45
# 49
# 44
# 44.25
# 45.8
# 40.8
# 41.45
# 43
# 38
# 52.25
# 53.8
# 48.8
# 49.45
# 51
# 46
# 40.25
# 41.8
# 36.8
# 37.45
# 39
# 34
# ...

# %%
import pandas as pd

result_phat = r"C:\Users\jschuler\Documents\CAB_Abac_charpentes\resultats"
result_glob = pd.read_csv(result_phat + r"\abaque_complet_global.csv", sep=";")
print(result_glob)
# Out:
#              id_config_calcul  id_produit  \
# 0     PANNE_DEVERSEE_P45_E1.2      100300
# 1     PANNE_DEVERSEE_P45_E1.2      100300
# 2     PANNE_DEVERSEE_P45_E1.2      100300
# 3     PANNE_DEVERSEE_P45_E1.2      100300
# 4     PANNE_DEVERSEE_P45_E1.2      100300
# ...                       ...         ...
# 4909     SOLIVE_PLANCHER_E0.6      104914
# 4910     SOLIVE_PLANCHER_E0.6      104914
# 4911     SOLIVE_PLANCHER_E0.6      104914
# 4912     SOLIVE_PLANCHER_E0.6      104914
# 4913     SOLIVE_PLANCHER_E0.6      104914
#
#                                                 libelle id_config_materiau  \
# 0     Bois massif about̩ KVH ̩picea C24 invisible ...       MAT_6d8bd866
# 1     Bois massif about̩ KVH ̩picea C24 invisible ...       MAT_6d8bd866
# 2     Bois massif about̩ KVH ̩picea C24 invisible ...       MAT_6d8bd866
# 3     Bois massif about̩ KVH ̩picea C24 invisible ...       MAT_6d8bd866
# 4     Bois massif about̩ KVH ̩picea C24 invisible ...       MAT_6d8bd866
# ...
